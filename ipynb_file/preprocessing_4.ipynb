# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2803005693.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]))[0]
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2803005693.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[1]))[0]
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2803005693.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[2]))[0]
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2803005693.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 272  D E C E M B E R         25       We Can Be Heroes
# 273  D E C E M B E R         25      News of the World
# 274  D E C E M B E R         25  One Night in Miami...
# 275  D E C E M B E R         25  Promising Young Woman
# 276  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 272  Netflix / Troublemaker Studios / Double R Prod...
# 273  Universal Pictures / Playtone / Perfect World ...
# 274                                     Amazon Studios
# 275          Focus Features / FilmNation Entertainment
# 276                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 272  Robert Rodriguez (director/screenplay); Priyan...  [245]
# 273  Paul Greengrass (director/screenplay); Luke Da...  [246]
# 274  Regina King (director); Kemp Powers (screenpla...  [247]
# 275  Emerald Fennell (director/screenplay); Carey M...  [248]
# 276  Kornél Mundruczó (director); Kata Wéber (scree...  [249]
#
# [277 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [277 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tmdbv3api in c:\users\abhay\appdata\roaming\python\python312\site-packages (1.9.0)
# Requirement already satisfied: requests in c:\users\abhay\appdata\roaming\python\python312\site-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhay\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhay\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhay\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhay\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (2024.2.2)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
import requests
import numpy as np
from tmdbv3api import Movie

# Initialize TMDb Movie instance
tmdb_movie = Movie()

def get_genre(movie_title):
    try:
        # Search for the movie
        result = tmdb_movie.search(movie_title)
        
        if not result:
            print(f"No results found for: {movie_title}")
            return np.NaN  # Return NaN if no results are found
        
        # Get movie ID from the search result
        movie_id = result[0].id

        # Fetch movie details using the ID
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        
        if response.status_code != 200:
            print(f"Failed to fetch details for movie ID {movie_id}: {response.status_code}")
            return np.NaN  # Return NaN if the API call fails

        # Parse the JSON response
        data_json = response.json()

        # Extract genres
        genres = []
        if 'genres' in data_json and data_json['genres']:
            for genre in data_json['genres']:
                genres.append(genre['name'])

        # Join genres into a single string
        return " ".join(genres) if genres else np.NaN

    except Exception as e:
        print(f"An error occurred: {e}")
        return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# Out:
# An error occurred: attribute name must be string, not 'int'
# An error occurred: attribute name must be string, not 'int'

# %%
''''from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN'''
'''from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN'''
# Out:
# 'from tmdbv3api import Movie\ntmdb_movie = Movie()\ndef get_genre(x):\n    genres = []\n    result = tmdb_movie.search(x)\n    movie_id = result[0].id\n    response = requests.get(\'https://api.themoviedb.org/3/movie/{}?api_key={}\'.format(movie_id,tmdb.api_key))\n    data_json = response.json()\n    if data_json[\'genres\']:\n        genre_str = " " \n        for i in range(0,len(data_json[\'genres\'])):\n            genres.append(data_json[\'genres\'][i][\'name\'])\n        return genre_str.join(genres)\n    else:\n        np.NaN'

# %%
#print(df_2020.columns)
#df_2020.columns = df_2020.columns.astype(str)
##ef get_genre(title):
    # Mock function for demonstration
   # if 'Action' in title:
    #    return 'Action'
    #lif 'Drama' in title:
      #  return 'Drama'
    #else:
     #   return 'Unknown'

#df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

'''df.columns = df.columns.astype(str)
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))'''
# Out:
# "df.columns = df.columns.astype(str)\ndf['genres'] = df['Title'].map(lambda x: get_genre(str(x)))"

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 272  D E C E M B E R         25       We Can Be Heroes
# 273  D E C E M B E R         25      News of the World
# 274  D E C E M B E R         25  One Night in Miami...
# 275  D E C E M B E R         25  Promising Young Woman
# 276  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 272  Netflix / Troublemaker Studios / Double R Prod...
# 273  Universal Pictures / Playtone / Perfect World ...
# 274                                     Amazon Studios
# 275          Focus Features / FilmNation Entertainment
# 276                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 272  Robert Rodriguez (director/screenplay); Priyan...  [245]
# 273  Paul Greengrass (director/screenplay); Luke Da...  [246]
# 274  Regina King (director); Kemp Powers (screenpla...  [247]
# 275  Emerald Fennell (director/screenplay); Carey M...  [248]
# 276  Kornél Mundruczó (director); Kata Wéber (scree...  [249]
#
#                                       genres
# 0                    Horror Mystery Thriller
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 272             Family Action Fantasy Comedy
# 273                  Drama Western Adventure
# 274                                    Drama
# 275                     Thriller Crime Drama
# 276                                    Drama
#
# [277 rows x 7 columns]

# %%
#df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
#df_2020
df_2020 = df[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres     director_name
# 0                    Horror Mystery Thriller     Nicolas Pesce
# 1    Horror Science Fiction Action Adventure    William Eubank
# 2                                     Comedy     Miguel Arteta
# 3                                      Drama         Jon Avnet
# 4                       Crime Thriller Drama    Anthony Jerjen
# ..                                       ...               ...
# 272             Family Action Fantasy Comedy  Robert Rodriguez
# 273                  Drama Western Adventure   Paul Greengrass
# 274                                    Drama       Regina King
# 275                     Thriller Crime Drama   Emerald Fennell
# 276                                    Drama  Kornél Mundruczó
#
# [277 rows x 4 columns]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\3646981363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\463054939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 272       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 273      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 274  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 275  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 276      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres     director_name  \
# 0                    Horror Mystery Thriller     Nicolas Pesce
# 1    Horror Science Fiction Action Adventure    William Eubank
# 2                                     Comedy     Miguel Arteta
# 3                                      Drama         Jon Avnet
# 4                       Crime Thriller Drama    Anthony Jerjen
# ..                                       ...               ...
# 272             Family Action Fantasy Comedy  Robert Rodriguez
# 273                  Drama Western Adventure   Paul Greengrass
# 274                                    Drama       Regina King
# 275                     Thriller Crime Drama   Emerald Fennell
# 276                                    Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 272  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 273              Tom Hanks      Helena Zengel              NaN
# 274      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 275         Carey Mulligan         Bo Burnham      Alison Brie
# 276          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [277 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 272  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 273   Paul Greengrass              Tom Hanks      Helena Zengel
# 274       Regina King      Kingsley Ben-Adir          Eli Goree
# 275   Emerald Fennell         Carey Mulligan         Bo Burnham
# 276  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                  Horror Mystery Thriller
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 272    YaYa Gosselin             Family Action Fantasy Comedy
# 273              NaN                  Drama Western Adventure
# 274      Aldis Hodge                                    Drama
# 275      Alison Brie                     Thriller Crime Drama
# 276     Molly Parker                                    Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 272       We Can Be Heroes
# 273      News of the World
# 274  One Night in Miami...
# 275  Promising Young Woman
# 276      Pieces of a Woman
#
# [277 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271       Pete Docter             Jamie Foxx           Tina Fey
# 272  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 274       Regina King      Kingsley Ben-Adir          Eli Goree
# 275   Emerald Fennell         Carey Mulligan         Bo Burnham
# 276  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                  Horror Mystery Thriller
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 271    Graham Norton          Animation Family Comedy Fantasy
# 272    YaYa Gosselin             Family Action Fantasy Comedy
# 274      Aldis Hodge                                    Drama
# 275      Alison Brie                     Thriller Crime Drama
# 276     Molly Parker                                    Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 271                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 272       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 274  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 275  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 276      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [248 rows x 7 columns]

# %%
old_df=pd.read_csv('D:\ldrp\dataset/final_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\2113129016.py:1: SyntaxWarning: invalid escape sequence '\l'
#   old_df=pd.read_csv('D:\ldrp\dataset/final_data.csv')

# %%
old_df = pd.read_csv('D:\ldrp\dataset/final_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\929363125.py:1: SyntaxWarning: invalid escape sequence '\l'
#   old_df = pd.read_csv('D:\ldrp\dataset/final_data.csv')

# %%
old_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 494                             Nick Bruno, Troy Quane
# 495                                       Greta Gerwig
# 496                                         Sam Mendes
# 497                              Destin Daniel Cretton
# 498                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 494                                  Will Smith             Tom Holland
# 495                               Saoirse Ronan             Emma Watson
# 496                               George MacKay    Dean-Charles Chapman
# 497                           Michael B. Jordan              Jamie Foxx
# 498                               Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                           Horror Thriller
# 1     Emily Althaus                             Drama Mystery
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 494   Rashida Jones  Animation Action Adventure Comedy Family
# 495   Florence Pugh                     Drama Romance History
# 496     Mark Strong                War History Thriller Drama
# 497     Brie Larson                       Drama Crime History
# 498     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 494        spies in disguise
# 495             little women
# 496                     1917
# 497               just mercy
# 498                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 494  Will Smith Tom Holland Rashida Jones Nick Brun...
# 495  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 496  George MacKay Dean-Charles Chapman Mark Strong...
# 497  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 498  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [499 rows x 7 columns]

# %%
final_df= pd.concat([old_df,new_df20 ], axis=0)

# %%
final_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 271                                        Pete Docter
# 272                                   Robert Rodriguez
# 274                                        Regina King
# 275                                    Emerald Fennell
# 276                                   Kornél Mundruczó
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 271                                  Jamie Foxx                Tina Fey
# 272                       Priyanka Chopra Jonas            Pedro Pascal
# 274                           Kingsley Ben-Adir               Eli Goree
# 275                              Carey Mulligan              Bo Burnham
# 276                               Vanessa Kirby            Shia LaBeouf
#
#        actor_3_name                           genres              movie_title  \
# 0    Leigh Whannell                  Horror Thriller  insidious: the last key
# 1     Emily Althaus                    Drama Mystery         the strange ones
# 2    Patrick Wilson          Action Thriller Mystery             the commuter
# 3       Billy Brown            Thriller Action Crime               proud mary
# 4     Shawn Ashmore            Action Crime Thriller         acts of violence
# ..              ...                              ...                      ...
# 271   Graham Norton  Animation Family Comedy Fantasy                     soul
# 272   YaYa Gosselin     Family Action Fantasy Comedy         we can be heroes
# 274     Aldis Hodge                            Drama    one night in miami...
# 275     Alison Brie             Thriller Crime Drama    promising young woman
# 276    Molly Parker                            Drama        pieces of a woman
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 271  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 272  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 274  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 275  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 276  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [747 rows x 7 columns]

# %%
final_df.to_csv('D:\ldrp\dataset\main_data.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\abhay\AppData\Local\Temp\ipykernel_16068\564408327.py:1: SyntaxWarning: invalid escape sequence '\l'
#   final_df.to_csv('D:\ldrp\dataset\main_data.csv',index=False)
